# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('test.csv')
train  = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
# ...

# %%
train.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count            2852.000000        3380.000000      3380.000000
# mean             4297.073879          19.075148        22.425740
# std              3298.508577         132.606895       133.527038
# min               468.770000           0.000000         1.000000
# 25%              1654.615000           3.000000         4.000000
# 50%              3068.915000           6.000000         5.000000
# 75%              5988.705000           8.000000         7.000000
# max             14710.533333        1777.000000      1486.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count    3380.000000          3380.000000           3306.000000
# mean       79.850296            21.784024             19.923775
# std       487.927461            15.103709            151.092122
# min         1.000000            -5.000000              0.000000
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3380 entries, 0 to 3379
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        3380 non-null   object
#  1   Customer_ID               3380 non-null   object
#  2   Month                     3380 non-null   object
#  3   Name                      3051 non-null   object
#  4   Age                       3380 non-null   object
#  5   SSN                       3380 non-null   object
#  6   Occupation                3380 non-null   object
#  7   Annual_Income             3380 non-null   object
#  8   Monthly_Inhand_Salary     2852 non-null   float64
#  9   Num_Bank_Accounts         3380 non-null   int64
#  10  Num_Credit_Card           3380 non-null   int64
#  11  Interest_Rate             3380 non-null   int64
#  12  Num_of_Loan               3380 non-null   object
# ...

# %%
train.isnull().sum()
# Out:
# ID                            0
# Customer_ID                   0
# Month                         0
# Name                        329
# Age                           0
# SSN                           0
# Occupation                    0
# Annual_Income                 0
# Monthly_Inhand_Salary       528
# Num_Bank_Accounts             0
# Num_Credit_Card               0
# Interest_Rate                 0
# Num_of_Loan                   0
# Type_of_Loan                440
# Delay_from_due_date           0
# Num_of_Delayed_Payment      223
# Changed_Credit_Limit          0
# Num_Credit_Inquiries         74
# Credit_Mix                    0
# Outstanding_Debt              0
# Credit_Utilization_Ratio      0
# Credit_History_Age          308
# Payment_of_Min_Amount         1
# Total_EMI_per_month           1
# Amount_invested_monthly     141
# Payment_Behaviour             1
# Monthly_Balance              47
# Credit_Score                  1
# dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6846 entries, 0 to 6845
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        6846 non-null   object
#  1   Customer_ID               6846 non-null   object
#  2   Month                     6846 non-null   object
#  3   Name                      6155 non-null   object
#  4   Age                       6846 non-null   object
#  5   SSN                       6846 non-null   object
#  6   Occupation                6846 non-null   object
#  7   Annual_Income             6846 non-null   object
#  8   Monthly_Inhand_Salary     5840 non-null   float64
#  9   Num_Bank_Accounts         6846 non-null   int64
#  10  Num_Credit_Card           6846 non-null   int64
#  11  Interest_Rate             6846 non-null   int64
#  12  Num_of_Loan               6846 non-null   object
# ...

# %%
test.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                         691
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       1006
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                 780
# Delay_from_due_date            0
# Num_of_Delayed_Payment       466
# Changed_Credit_Limit           0
# Num_Credit_Inquiries         139
# Credit_Mix                     0
# Outstanding_Debt               1
# Credit_Utilization_Ratio       1
# Credit_History_Age           609
# Payment_of_Min_Amount          1
# Total_EMI_per_month            1
# Amount_invested_monthly      300
# Payment_Behaviour              1
# Monthly_Balance               76
# dtype: int64

# %%
plt.figure(figsize = (15,15))
num  = 1
for i in train.columns:
  if num <= 20:
    plt.subplot(5,5,num)
    sns.boxplot(train[i])
  num +=1
plt.show()

# %%
plt.figure(figsize = (15,15))
num  = 1
for i in train.columns:
  if num <= 20:
    plt.subplot(5,5,num)
    sns.lineplot(train[i])
  num +=1
plt.show()

# %%
nu = train.select_dtypes(include = ['float64','int64']).columns

# %%
s = train.select_dtypes(include = object).columns
s
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Num_of_Loan', 'Type_of_Loan',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Credit_Score'],
#       dtype='object')

# %%
train[s]
# Out:
#           ID Customer_ID     Month           Name   Age          SSN  \
# 0     0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1     0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2     0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3     0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4     0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...      ...         ...       ...            ...   ...          ...
# 3375  0x29c5  CUS_0xad9d    August  Valentina Zaf    23  771-56-8439
# 3376  0x29ca  CUS_0x9776   January      Carolinex    40  703-80-5465
# 3377  0x29cb  CUS_0x9776  February      Carolinex    40  703-80-5465
# 3378  0x29cc  CUS_0x9776     March      Carolinex    40  703-80-5465
# 3379  0x29cd  CUS_0x9776     April      Carolinex   40_  703-80-5465
#
#      Occupation Annual_Income Num_of_Loan  \
# 0     Scientist      19114.12           4
# 1     Scientist      19114.12           4
# ...

# %%
from sklearn.impute import SimpleImputer
sas = SimpleImputer(missing_values=np.nan ,strategy= 'most_frequent')
train[s] = sas.fit_transform(train[s])

# %%
train[s]
# Out:
#           ID Customer_ID     Month           Name   Age          SSN  \
# 0     0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1     0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2     0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3     0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4     0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...      ...         ...       ...            ...   ...          ...
# 3375  0x29c5  CUS_0xad9d    August  Valentina Zaf    23  771-56-8439
# 3376  0x29ca  CUS_0x9776   January      Carolinex    40  703-80-5465
# 3377  0x29cb  CUS_0x9776  February      Carolinex    40  703-80-5465
# 3378  0x29cc  CUS_0x9776     March      Carolinex    40  703-80-5465
# 3379  0x29cd  CUS_0x9776     April      Carolinex   40_  703-80-5465
#
#      Occupation Annual_Income Num_of_Loan  \
# 0     Scientist      19114.12           4
# 1     Scientist      19114.12           4
# ...

# %%
sas2 = SimpleImputer(missing_values=np.nan ,strategy = 'mean')
train[nu] = sas2.fit_transform(train[nu])

# %%
train[s].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3380 entries, 0 to 3379
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       3380 non-null   object
#  1   Customer_ID              3380 non-null   object
#  2   Month                    3380 non-null   object
#  3   Name                     3380 non-null   object
#  4   Age                      3380 non-null   object
#  5   SSN                      3380 non-null   object
#  6   Occupation               3380 non-null   object
#  7   Annual_Income            3380 non-null   object
#  8   Num_of_Loan              3380 non-null   object
#  9   Type_of_Loan             3380 non-null   object
#  10  Num_of_Delayed_Payment   3380 non-null   object
#  11  Changed_Credit_Limit     3380 non-null   object
#  12  Credit_Mix               3380 non-null   object
#  13  Outstanding_Debt         3380 non-null   object
# ...

# %%
s
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Num_of_Loan', 'Type_of_Loan',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Credit_Score'],
#       dtype='object')

# %%
train[s].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3380 entries, 0 to 3379
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       3380 non-null   object
#  1   Customer_ID              3380 non-null   object
#  2   Month                    3380 non-null   object
#  3   Name                     3380 non-null   object
#  4   Age                      3380 non-null   object
#  5   SSN                      3380 non-null   object
#  6   Occupation               3380 non-null   object
#  7   Annual_Income            3380 non-null   object
#  8   Num_of_Loan              3380 non-null   object
#  9   Type_of_Loan             3380 non-null   object
#  10  Num_of_Delayed_Payment   3380 non-null   object
#  11  Changed_Credit_Limit     3380 non-null   object
#  12  Credit_Mix               3380 non-null   object
#  13  Outstanding_Debt         3380 non-null   object
# ...

# %%
train[s] = train[s].astype(str)
from sklearn.preprocessing import LabelEncoder
x= LabelEncoder()
for i in s:
  train[i] = x.fit_transform(train[i])

# %%
t_sas = test.select_dtypes(include = ['int64','float64']).columns
test[t_sas]
# Out:
#       Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0               1824.843333                  3                4
# 1               1824.843333                  3                4
# 2               1824.843333                  3                4
# 3                       NaN                  3                4
# 4               3037.986667                  2                4
# ...                     ...                ...              ...
# 6841            2200.781667                  3             1356
# 6842                    NaN                  3                5
# 6843            2200.781667                  3                5
# 6844            6744.100000                  9                5
# 6845            6744.100000                  8                4
#
#       Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# 0                 3                    3                2022.0
# 1                 3                    3                   4.0
# ...

# %%
t_obj = test.select_dtypes(include = ['object']).columns

# %%
ss1 = SimpleImputer(missing_values=np.nan, strategy= 'most_frequent')
test[t_obj] = ss1.fit_transform(test[t_obj])

# %%
ss2 = SimpleImputer(strategy= 'mean')
test[t_sas] = ss1.fit_transform(test[t_sas])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3380 entries, 0 to 3379
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        3380 non-null   int64
#  1   Customer_ID               3380 non-null   int64
#  2   Month                     3380 non-null   int64
#  3   Name                      3380 non-null   int64
#  4   Age                       3380 non-null   int64
#  5   SSN                       3380 non-null   int64
#  6   Occupation                3380 non-null   int64
#  7   Annual_Income             3380 non-null   int64
#  8   Monthly_Inhand_Salary     3380 non-null   float64
#  9   Num_Bank_Accounts         3380 non-null   float64
#  10  Num_Credit_Card           3380 non-null   float64
#  11  Interest_Rate             3380 non-null   float64
#  12  Num_of_Loan               3380 non-null   int64
# ...

# %%
s
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Num_of_Loan', 'Type_of_Loan',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Credit_Score'],
#       dtype='object')

# %%
train[s].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3380 entries, 0 to 3379
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       3380 non-null   int64
#  1   Customer_ID              3380 non-null   int64
#  2   Month                    3380 non-null   int64
#  3   Name                     3380 non-null   int64
#  4   Age                      3380 non-null   int64
#  5   SSN                      3380 non-null   int64
#  6   Occupation               3380 non-null   int64
#  7   Annual_Income            3380 non-null   int64
#  8   Num_of_Loan              3380 non-null   int64
#  9   Type_of_Loan             3380 non-null   int64
#  10  Num_of_Delayed_Payment   3380 non-null   int64
#  11  Changed_Credit_Limit     3380 non-null   int64
#  12  Credit_Mix               3380 non-null   int64
#  13  Outstanding_Debt         3380 non-null   int64
# ...

# %%
for i in s:
  from sklearn.preprocessing import LabelEncoder
  x= LabelEncoder()
  train[i] = x.fit_transform(train[i])

# %%
x_train = train.drop('Credit_Score',axis =1)
y_train = train['Credit_Score']

# %%
from sklearn.naive_bayes import GaussianNB
gb = GaussianNB()
gb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
x_pred = gb.predict(x_train)

# %%
x_test = train

# %%
gb.score(x_train,y_train)
# Out:
# 0.6029585798816568

# %%
from sklearn.metrics import accuracy_score
accuracy_score(x_pred,y_train)
# Out:
# 0.6029585798816568

# %%
train['Num_of_Delayed_Payment']
# Out:
# 0       70
# 1       20
# 2       70
# 3       62
# 4       20
#         ..
# 3375    65
# 3376    10
# 3377    10
# 3378    12
# 3379    18
# Name: Num_of_Delayed_Payment, Length: 3380, dtype: int64

# %%
v = train.groupby('Credit_Score')['Num_of_Delayed_Payment'].nlargest(5)

# %%
v
# Out:
# Credit_Score
# 0             654     78
#               648     77
#               649     77
#               651     77
#               652     77
# 1             104     77
#               105     77
#               108     77
#               110     77
#               111     77
# 2             2061    78
#               26      77
#               31      77
#               225     77
#               520     77
# Name: Num_of_Delayed_Payment, dtype: int64
